# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('All_attendee.csv')

# %%
data.head(50)
# Out:
#    Attended            First Name        Last Name  \
# 0       Yes              Adeyinka         Oresanya
# 1       Yes                Soumya           Sharma
# 2       Yes              Bhagawan           Subedi
# 3       Yes                 David          Bodunde
# 4       Yes              girijesh              NaN
# 5       Yes           OGUNJUYIGBE              NaN
# 6       Yes                 gorja              NaN
# 7       Yes                  Abba           Kwaise
# 8       Yes              Ayantoye            jesse
# 9       Yes               Yolanda        Romaulimm
# 10      Yes              Abhishek                M
# 11      Yes                 Juwon           Saromi
# 12      Yes                  Mani           Sarkar
# 13      Yes                Bassey             Akan
# 14      Yes             Nathaniel              NaN
# 15      Yes  DSN/AIPlus/2019/0065              NaN
# 16      Yes                  Emma              NaN
# ...

# %%
# #Number of regions represented in the webinar
# alex = data['Country/Region Name'] == 'alexander.ifenaike@gmail.com'
# alex

# %%
#Top 10 region present
data['Country/Region Name'].value_counts().head(10)
# Out:
# Nigeria                     94
# India                       74
# Missing                     57
# United States of America     8
# Indonesia                    6
# United Kingdom               3
# South Africa                 3
# Kenya                        2
# Germany                      2
# Morocco                      2
# Name: Country/Region Name, dtype: int64

# %%
emails_data_grant = pd.read_csv('Data_grant_emails.csv')
emails_data_grant
# Out:
#                             Emails    FirstName   LastName Unnamed: 3
# 0     alexander.ifenaike@gmail.com     Ifenaike  Alexander        NaN
# 1   olayinkaakinwonjowo6@gmail.com  Akinwonjowo   Olayinka   Titilope
# 2              awepius62@gmail.com   Boluwatife        Awe        NaN
# 3          yusufokunlola@gmail.com        Yusuf   Okunlola        NaN
# 4      abegunde.michael2@gmail.com     Abegunde    Adedayo    Michael
# ..                             ...          ...        ...        ...
# 56  josepholadipupoibeun@gmail.com    Oladipupo      Ibeun        NaN
# 57             topzeetee@gmail.com        Gbede   Temitope        NaN
# 58         abuosayuwamen@yahoo.com   Osayuwamen        Abu        NaN
# 59         rexsimiloluwa@gmail.com   Similoluwa    Okunowo        NaN
# 60                             NaN          NaN        NaN        NaN
#
# [61 rows x 4 columns]

# %% [markdown]
# ### Write a program that print email of data grant beneficiaries not in attendance emails

# %%
def Validate_attendance_email(all_attendance, emails_data_grantees):
    emails_all = list(all_attendance['Email'])
    not_present = []
    for emails in list(emails_data_grantees):
        if emails not in emails_all:
            not_present.append(emails)
            
#     culprit_email = pd.DataFrame(not_present, ['Email'])
            
    return not_present

# def Validate_FirstName():
#     mail_checklist = Validate_attendance_email(all_attendance = data, emails_data_grantees = emails_data_grant.Emails)
#     for mail in mail_checklist:
#         if mail in emails_data_grant.Emails:
#             print(emails_data_grant[mail])
    
    
                                 
check_list = Validate_attendance_email(all_attendance = data, emails_data_grantees = emails_data_grant.Emails)
check_list
# Out:
# ['Ogundipe72@gmail.com',
#  'amazingictdevelopers@gmail.com',
#  'Awosikuvivian9@gmail.com',
#  'Benjjy4u@gmail.com',
#  'olawuyioluvic@gmail.com',
#  'bolulayo70@gmail.com',
#  'okewunmipaul@yahoo.com',
#  'aderinolaruqayaah@gmail.com',
#  'olugbengamotunrayo42763@gmail.com',
#  'adegbitetomiwa@gmail.com',
#  'oluwaseyiadara95@gmail.com',
#  'timilehinamos@gmail.com',
#  'samuelfadunsin@gmail.com',
#  'feromatadama@gmail.com',
#  'fuadadio75@gmail.com',
#  'azonobi@yahoo.com',
#  'akinrembunmi111@gmail.com',
#  'adamzmuhammad21@gmail.Com',
#  'topzeetee@gmail.com',
#  'abuosayuwamen@yahoo.com',
#  nan]

# %%
# def Validate_FirstName(all_attendance, email_data_grant):
#     mail_checklist = Validate_attendance_email(all_attendance = data, emails_data_grantees = emails_data_grant.Emails)
#     for mail in mail_checklist:
#         if mail in emails_data_grant.Emails:
#             print(emails_data_grant[mail])
            
# Validate_FirstName(all_attendance = data, email_data_grant = emails_data_grant)

# %%
[
 'Ogundipe72@gmail.com',
 'amazingictdevelopers@gmail.com',
 'Awosikuvivian9@gmail.com',
 'Benjjy4u@gmail.com',
 'olawuyioluvic@gmail.com',
 'bolulayo70@gmail.com',
 'okewunmipaul@yahoo.com',
 'aderinolaruqayaah@gmail.com',
 'olugbengamotunrayo42763@gmail.com',
 'adegbitetomiwa@gmail.com',
 'oluwaseyiadara95@gmail.com',
 'timilehinamos@gmail.com',
 'samuelfadunsin@gmail.com',
 'feromatadama@gmail.com',
 'fuadadio75@gmail.com',
 'azonobi@yahoo.com',
 'akinrembunmi111@gmail.com',
 'adamzmuhammad21@gmail.Com',
 'topzeetee@gmail.com',
 'abuosayuwamen@yahoo.com',]

# %%
emails_data_grant.Emails
# Out:
# 0          alexander.ifenaike@gmail.com
# 1        olayinkaakinwonjowo6@gmail.com
# 2                   awepius62@gmail.com
# 3               yusufokunlola@gmail.com
# 4           abegunde.michael2@gmail.com
# 5                   bvcious10@gmail.com
# 6            fadekemiogundiya@gmail.com
# 7               jesseayantoye@gmail.com
# 8              sanusiadeniyi1@gmail.com
# 9            adeyinkaoresanya@gmail.com
# 10             allisonabiodun@gmail.com
# 11                benstuber.g@gmail.com
# 12           damilaretaiwo111@gmail.com
# 13                 Ogundipe72@gmail.com
# 14                isahabdul16@gmail.com
# 15           oladapoabdusalam@gmail.com
# 16                  szulykhoh@gmail.com
# 17        ayodabooluwatomisin@gmail.com
# 18              vikingdavid41@gmail.com
# 19       amazingictdevelopers@gmail.com
# 20                  kennyoje1@gmail.com
# 21             Awosikuvivian9@gmail.com
# 22            komolehinisrael@gmail.com
# ...
